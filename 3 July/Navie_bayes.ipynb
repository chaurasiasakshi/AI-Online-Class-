# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn import datasets

# %%
data = {
    "Name":['Saksham','Sakshi','Ambika','Richa','Aman','Pravesh','Ashish','Atul','Ramakant','Raja'],
    "Marks":[85,56,78,90,62,71,88,57,93,47],
    "Hours":[7,5,6,8,5,6,7,4,8,3],
    "Result":['Pass','Fail','Pass','Pass','Fail','Pass','Pass','Pass','Pass','Fail']
    
}

# %%
df = pd.DataFrame(data)

# %%
df.to_csv('std.csv',index=False)

# %%
df
# Out:
#        Name  Marks  Hours Result
# 0   Saksham     85      7   Pass
# 1    Sakshi     56      5   Fail
# 2    Ambika     78      6   Pass
# 3     Richa     90      8   Pass
# 4      Aman     62      5   Fail
# 5   Pravesh     71      6   Pass
# 6    Ashish     88      7   Pass
# 7      Atul     57      4   Pass
# 8  Ramakant     93      8   Pass
# 9      Raja     47      3   Fail

# %%
a = pd.read_csv('std.csv')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
le
# Out:
# LabelEncoder()

# %%
a['Result'] = le.fit_transform(a['Result'])

# %%
a
# Out:
#        Name  Marks  Hours  Result
# 0   Saksham     85      7       1
# 1    Sakshi     56      5       0
# 2    Ambika     78      6       1
# 3     Richa     90      8       1
# 4      Aman     62      5       0
# 5   Pravesh     71      6       1
# 6    Ashish     88      7       1
# 7      Atul     57      4       1
# 8  Ramakant     93      8       1
# 9      Raja     47      3       0

# %%
# a['Result'] = a['Result'].apply(lambda x : 1 if x=='Pass' else 0)

# %%
a
# Out:
#        Name  Marks  Hours  Result
# 0   Saksham     85      7       1
# 1    Sakshi     56      5       0
# 2    Ambika     78      6       1
# 3     Richa     90      8       1
# 4      Aman     62      5       0
# 5   Pravesh     71      6       1
# 6    Ashish     88      7       1
# 7      Atul     57      4       1
# 8  Ramakant     93      8       1
# 9      Raja     47      3       0

# %%
x = a.drop(['Result','Name'],axis=1)

# %%
x
# Out:
#    Marks  Hours
# 0     85      7
# 1     56      5
# 2     78      6
# 3     90      8
# 4     62      5
# 5     71      6
# 6     88      7
# 7     57      4
# 8     93      8
# 9     47      3

# %%
y = a['Result']

# %%
y
# Out:
# 0    1
# 1    0
# 2    1
# 3    1
# 4    0
# 5    1
# 6    1
# 7    1
# 8    1
# 9    0
# Name: Result, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#    Marks  Hours
# 5     71      6
# 0     85      7
# 7     57      4
# 2     78      6
# 9     47      3
# 4     62      5
# 3     90      8
# 6     88      7

# %%
y_test
# Out:
# 8    1
# 1    0
# Name: Result, dtype: int64

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()

# %%
gnb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred = gnb.predict(x_test)

# %%
y_pred
# Out:
# array([1, 0])

# %%
gnb.score(x_test,y_test)
# Out:
# 1.0

# %%
from sklearn.metrics import accuracy_score , classification_report , confusion_matrix

# %%
pr = gnb.predict([[33,8]])
pr
# Out:
# C:\Users\Asus\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array([1])

# %%
le.inverse_transform(pr)
# Out:
# array(['Pass'], dtype=object)

# %%
acc = accuracy_score(y_test,y_pred)
acc
# Out:
# 1.0
